# %%
import pandas as pd

df = pd.read_csv('../data/wine_data.csv')
df
# Out:
#      Alcohol  Malic   Ash  Alcalinity  Magesium  Phenols  Flavanoids  \
# 0      14.23   1.71  2.43        15.6       127     2.80        3.06
# 1      13.20   1.78  2.14        11.2       100     2.65        2.76
# 2      13.16   2.36  2.67        18.6       101     2.80        3.24
# 3      14.37   1.95  2.50        16.8       113     3.85        3.49
# 4      13.24   2.59  2.87        21.0       118     2.80        2.69
# ..       ...    ...   ...         ...       ...      ...         ...
# 173    13.71   5.65  2.45        20.5        95     1.68        0.61
# 174    13.40   3.91  2.48        23.0       102     1.80        0.75
# 175    13.27   4.28  2.26        20.0       120     1.59        0.69
# 176    13.17   2.59  2.37        20.0       120     1.65        0.68
# 177    14.13   4.10  2.74        24.5        96     2.05        0.76
#
#      Nonflavanoids  Proanthocyanins  Color   Hue  Dilution  Proline  class
# ...

# %%
from my_functions import create_feature_target, clf_eval

X_train, X_test, y_train, y_test = create_feature_target(df)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pca.fit(X_train)
X_train_pca = pca.transform(X_train)
X_test_pca = pca.transform(X_test)

# %%
print(X_train_pca.shape)
print(X_test_pca.shape)
# Out:
# (142, 2)
# (36, 2)

# %%
print(pca.singular_values_)
# Out:
# [26.09369    18.88432045]

# %%
print(pca.components_)
# Out:
# [[ 0.12959991 -0.24464064 -0.01018912 -0.24051579  0.12649451  0.38944115
#    0.42757808 -0.30505669  0.30775255 -0.11027186  0.30710508  0.37636185
#    0.2811085 ]
#  [-0.49807323 -0.23168482 -0.31496874  0.02321825 -0.25841951 -0.1006849
#   -0.02097952 -0.0399057  -0.06746036 -0.53087111  0.27161729  0.16071181
#   -0.36547344]]

# %%
print(pca.explained_variance_)
# Out:
# [4.82894083 2.52920254]

# %%
print(pca.explained_variance_ratio_)
# Out:
# [0.36884109 0.19318394]

# %%
pca_columns = ['pca_comp1', 'pca_comp2']
X_train_pca_df = pd.DataFrame(X_train_pca, columns=pca_columns)
y_tn1 = y_test.reset_index(drop=True)
X_train_pca_df['target'] = y_tn1
X_train_pca_df.head(10)
# Out:
#    pca_comp1  pca_comp2  target
# 0  -2.178845  -1.072185     0.0
# 1  -1.808192   1.578223     2.0
# 2   1.098295   2.221243     1.0
# 3  -2.555847  -1.662104     0.0
# 4   1.856981   0.241573     1.0
# 5   2.582886  -1.376682     1.0
# 6   0.872876   2.256185     0.0
# 7  -0.418384   2.354157     2.0
# 8  -0.304977   2.276594     1.0
# 9   2.140825  -1.100529     1.0
