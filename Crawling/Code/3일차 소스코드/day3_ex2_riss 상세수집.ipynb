# %%
# Chap 15.riss.kr 에서 특정 키워드로 논문 / 학술 자료 검색하기

#Step 1. 필요한 모듈을 로딩합니다
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
# from selenium.webdriver.chrome.service import Service
import time 

#Step 2. 사용자에게 검색 관련 정보들을 입력 받습니다.
query_txt = input("1. 검색할 텍스트를 입력해주세요: ")
cnt = int(input("2. 검색할 건수를 입력하세요: "))


#Step 3. 수집된 데이터를 저장할 파일 이름 입력받기 
f_dir = input("3. 파일을 저장할 폴더명만 쓰세요(기본값:c:\\py_temp\\):")
if f_dir == '' :
    f_dir="c:\\py_temp\\"

#Step 4. 크롬 드라이버 설정 및 웹 페이지 열기
driver = webdriver.Chrome()
url = 'http://www.riss.kr/'
driver.get(url)
driver.maximize_window()
time.sleep(2)

main = driver.window_handles
for handle in main:
    if handle != main[0]:
        driver.switch_to.window(handle)
        driver.close()

driver.switch_to.window(driver.window_handles[0])

#Step 5. 자동으로 검색어 입력 후 조회하기
driver.find_element(By.ID,'query').send_keys(query_txt+'\n')

#Step 6.학위 논문 선택하기
driver.find_element(By.LINK_TEXT,'학위논문').click()
time.sleep(2)

#Step 7.Beautiful Soup 로 본문 내용만 추출하기
from bs4 import BeautifulSoup
soup_1 = BeautifulSoup(driver.page_source, 'html.parser')

#Step 8. 총 검색 건수를 보여주고 수집할 건수 입력받기
import math
total_cnt = soup_1.find('div','searchBox pd').find('span','num').get_text()
print('검색하신 키워드 %s (으)로 총 %s 건의 학위논문이 검색되었습니다' %(query_txt,total_cnt))
page_cnt = math.ceil(cnt / 10)
print('%s 건의 데이터를 수집하기 위해 %s 페이지의 게시물을 조회합니다.' %(cnt,page_cnt))
print("\n")

#Step 9. 데이터 수집하기
no2=[]           # 게시글 번호 컬럼
title2=[]       # 게시글 제목 컬럼
author2=[]       # 논문 저자 컬럼
company2=[]     # 소속 기관 컬럼
date2=[]        # 게시글 날짜 컬럼
suksa2=[]       # 국내석사 컬럼
contents2=[]     # 초록내용
full_url2=[]     # 논문 원본 URL

no = 1           # 게시글 번호 초기값
            
for a in range(1,page_cnt+1) :
    time.sleep(2)
    print("\n")
    print("%s 페이지 내용 수집 시작합니다 =======================" %a)

    soup = BeautifulSoup(driver.page_source, 'html.parser')
    content_list = soup.find('div','srchResultListW').find_all('li')

    for i in content_list:
        # 논문 제목 체크하기
        try:
            title=i.find('p','title').get_text().strip()
        except :
            continue 
        else :
            # 1.게시글 번호
            print("\n")
            print("%s 번째 정보를 추출하고 있습니다============" %no)
            no2.append(no)
            print("1.번호 : %s" %no)
            
            # 2. 논문 제목
            title2.append(title.strip())
            print("2.제목 : %s" %title.strip())

            # 3. 작성자
            try :
                author=i.find('p','etc').find('span','writer').get_text().strip()
            except :
                author = '작성자가 없습니다'
                print("3.작성자 : %s" %author.strip())
                author2.append(author.strip())
            else :
                author2.append(author.strip())
                print("3.작성자 : %s" %author.strip())

            # 4. 소속기관
            try :
                company=i.find('p','etc').find('span','assigned').get_text().strip()
            except :
                company='소속 기관이 없습니다'
                company2.append(company.strip())
                print("4.소속기관 : %s" %company.strip())
            else :
                company2.append(company.strip())
                print("4.소속기관 : %s" %company.strip())

            # 5. 발표날짜
            try :
                date_1 =i.find('p','etc').find_all('span')
                date_2 = date_1[2].get_text().strip()
            except :
                date_2='발표날짜가 없습니다'
                date2.append(date_2)
                print("5.발표년도 : %s" %date_2)
            else :
                date2.append(date_2)
                print("5.발표년도 : %s" %date_2)

            # 6.학위여부
            try :
                suksa_1 =i.find('p','etc').find_all('span')
                suksa_2 = suksa_1[3].get_text().strip()
            except :
                suksa_2='학위가 없습니다'
                suksa2.append(suksa_2)
                print("6.학위여부 : %s" %suksa_2)
            else :
                suksa2.append(suksa_2)
                print("6.학위여부 : %s" %suksa_2)

            # 7.초록 내용-해당 논문의 상세 내역에서 추출할 수 있음.    
            url_1 = i.find('p','title').find('a')['href']
            full_url = 'http://www.riss.kr'+url_1
            time.sleep(1)
            driver.get(full_url)

            soup_1 = BeautifulSoup(driver.page_source, 'html.parser')  
            try :
                cont=soup_1.find("div","text").find('p').get_text().replace("\n","").strip()
            except :
                cont='초록이 없습니다'
                contents2.append(cont)
                print("7.초록내용 : %s" %cont)
            else :
                contents2.append(cont)
                print("7.초록내용 : %s" %cont)

            time.sleep(1)

            # 8.논문 url 주소
            full_url2.append(full_url)
            print('8.논문 URL 주소:' , full_url)

            driver.back()  # 이전 페이지로 돌아가기

            time.sleep(2)

            no += 1
            
            if no > cnt :
                break 
                            
    a += 1 
    b = str(a)

    try :
        driver.find_element(By.LINK_TEXT ,'%s' %b).click() 
    except :
        driver.find_element(By.LINK_TEXT,'다음 페이지로').click()
        
print("요청하신 작업이 모두 완료되었습니다")

# Step 10. 수집된 데이터를 xls와 csv 형태로 저장하기
# 현재 날짜와 시간으로 폴더 만들고 파일 이름 설정하기
import os

n = time.localtime()
s = '%04d-%02d-%02d-%02d-%02d-%02d' %(n.tm_year, n.tm_mon, n.tm_mday, n.tm_hour, n.tm_min, n.tm_sec)

os.makedirs(f_dir+'RISS'+'-'+s+'-'+'학위논문')

fc_name = f_dir+'RISS'+'-'+s+'-'+'학위논문'+'\\'+'RISS'+'-'+s+'-'+'학위논문'+'.csv'
fx_name = f_dir+'RISS'+'-'+s+'-'+'학위논문'+'\\'+'RISS'+'-'+s+'-'+'학위논문'+'.xls'

# 데이터 프레임 생성 후 xls , csv 형식으로 저장하기
import pandas as pd 

df = pd.DataFrame()
df['번호']=no2
df['제목']=pd.Series(title2)
df['저자']=pd.Series(author2)
df['소속(발행)기관']=pd.Series(company2)
df['날짜']=pd.Series(date2)
df['학위(논문일경우)']=pd.Series(suksa2)
df['초록(논문일경우)']=pd.Series(contents2)
df['자료URL주소']=pd.Series(full_url2)

# xls 형태로 저장하기
df.to_excel(fx_name, index=False, engine='openpyxl')

# csv 형태로 저장하기
df.to_csv(fc_name, index=False, encoding="utf-8-sig")

print('요청하신 데이터 수집 작업이 정상적으로 완료되었습니다')
# Out:
# 검색하신 키워드 딥러닝 (으)로 총 6,056 건의 학위논문이 검색되었습니다
# 30 건의 데이터를 수집하기 위해 3 페이지의 게시물을 조회합니다.
#
#
#
#
# 1 페이지 내용 수집 시작합니다 =======================
#
#
# 1 번째 정보를 추출하고 있습니다============
# 1.번호 : 1
# 2.제목 : 딥러닝을 이용한 해석 가능한 함수 추정에 관한 연구
# 3.작성자 : 송낙윤
# 4.소속기관 : 명지대학교 대학원
# 5.발표년도 : 2018
# 6.학위여부 : 국내석사
# 7.초록내용 : 인공지능은 1997년 체스게임에서 인간에게 승리를 거둔 것을 시작으로 다양한 분야, 다양한 과제에서 인간의 능력을 뛰어넘는 결과를 내고 있다. 이러한 결과의 배경에는 대량의 연산을 가능...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=d9b99d4a1dd4f667ffe0bdc3ef48d419&keyword=딥러닝
#
#
# 2 번째 정보를 추출하고 있습니다============
# 1.번호 : 2
# 2.제목 : 딥러닝과 Dilation-Erosion 기법을 접목한 영상 기반 정밀 균열 평가 기술
# 3.작성자 : 배숙경
# 4.소속기관 : 서울시립대학교 일반대학원
# 5.발표년도 : 2022
# 6.학위여부 : 국내석사
# 7.초록내용 : 구조물에서 발생한 균열을 효과적으로 탐지하기 위해 딥러닝과 영상기반 점검 기술을 접목한 많은 연구들이 있었다. 일부 연구에서는 균열 영역을 균열의 외부까지 포함하는 라벨링을 수행...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=20a69245a65034b1ffe0bdc3ef48d419&keyword=딥러닝
#
#
# 3 번째 정보를 추출하고 있습니다============
# 1.번호 : 3
# 2.제목 : 딥러닝 및 관련 기법을 활용한 철근 가격 장단기예측
# 3.작성자 : 이용성
# 4.소속기관 : 건국대학교 대학원
# 5.발표년도 : 2022
# 6.학위여부 : 국내박사
# 7.초록내용 : The price of the building materials such as steel, wood, and insulation have recently soared alongside rises in raw material prices. In particular, the rebar price’s frequent fluctuations due to the macroeconomic influences have again hit the highes...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=16320d0e423e6ee9ffe0bdc3ef48d419&keyword=딥러닝
#
#
# 4 번째 정보를 추출하고 있습니다============
# 1.번호 : 4
# 2.제목 : 딥러닝 알고리즘을 이용한 건설공사 공기예측의 적정성 분석
# 3.작성자 : 안현주
# 4.소속기관 : 경상대학교 대학원
# 5.발표년도 : 2020
# 6.학위여부 : 국내석사
# 7.초록내용 : 건설 프로젝트에서 공정관리는 프로젝트의 성공적인 수행에 있어 중요한 업무범위이며 공사계약 체결, 공사비 산정 등의 중요한 사항을 좌우한다. 현재 건설 프로젝트의 공기산정 방식은 ...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=4f3696d93d904e72ffe0bdc3ef48d419&keyword=딥러닝
#
#
# 5 번째 정보를 추출하고 있습니다============
# 1.번호 : 5
# 2.제목 : 딥러닝 기반 객체 분류에 의한 토지사용 현황 분석에 관한 연구 - 창원시 사례를 중심으로 -
# 3.작성자 : 김순한
# 4.소속기관 : 서울시립대학교 대학원
# 5.발표년도 : 2022
# 6.학위여부 : 국내석사
# 7.초록내용 : 국공유지 토지사용 현황을 파악하여 국공유지 불법점용을 파악하고 개발 등에 활용하기 위해서 지속적으로 현장조사를 진행하여 왔으나 이는 시간과 비용이 많이 들고 정보 최신성을 확보...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=f499bd10396a087cffe0bdc3ef48d419&keyword=딥러닝
#
#
# 6 번째 정보를 추출하고 있습니다============
# 1.번호 : 6
# 2.제목 : 딥러닝 모델 기반 스케일업 LULUCF 매트릭스 구축에 관한 연구
# 3.작성자 : 박정묵
# 4.소속기관 : 강원대학교 대학원
# 5.발표년도 : 2019
# 6.학위여부 : 국내박사
# 7.초록내용 : 본 연구는 2020년 신기후체제에 대응하기 위하여 국제적 기준에 부합하는 국내 온실가스 인벤토리의 LULUCF분야 국가통계 구축 개발을 목적으로 하였다.  우리나라 국가인벤토리보고서(NIR)의 ...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=1c8130db499ba63affe0bdc3ef48d419&keyword=딥러닝
#
#
# 7 번째 정보를 추출하고 있습니다============
# 1.번호 : 7
# 2.제목 : 딥러닝을 이용한 일별 천연가스 수요 예측
# 3.작성자 : 김헌주
# 4.소속기관 : 성균관대학교 일반대학원
# 5.발표년도 : 2022
# 6.학위여부 : 국내석사
# 7.초록내용 : 천연가스는 석유와 함께 인간에게 필요한 에너지원으로 현재 기후정책 및 에너지 전환 시대를 맞아 중요성이 점차 확대되고 있다. 국내에서 사용되는 천연가스의 대부분은 수입에 의존하고...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=c5f1093f87602cebffe0bdc3ef48d419&keyword=딥러닝
#
#
# 8 번째 정보를 추출하고 있습니다============
# 1.번호 : 8
# 2.제목 : PVD를 활용한 딥러닝 기반 도심부 링크 통행속도 추정 알고리즘 개발
# 3.작성자 : 박건규
# 4.소속기관 : 명지대학교 대학원
# 5.발표년도 : 2022
# 6.학위여부 : 국내석사
# 7.초록내용 : 초록이 없습니다
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=ef66dd8f97dba8c4ffe0bdc3ef48d419&keyword=딥러닝
#
#
# 9 번째 정보를 추출하고 있습니다============
# 1.번호 : 9
# 2.제목 : 딥러닝 구름 탐지 기반 NOAA/AVHRR 해수면온도 정확도 향상 연구
# 3.작성자 : 최도영
# 4.소속기관 : 서울대학교 대학원
# 5.발표년도 : 2019
# 6.학위여부 : 국내석사
# 7.초록내용 : 해수면온도는 해양과 대기 현상을 이해하기 위한 가장 기본적인 변수로써 해수면온도로 해양 상층에 존재하는 다양한 해양 현상을 관측할 수 있으며, 해양-대기와의 상호작용을 통해 기상 ...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=2412925cb9e107a7ffe0bdc3ef48d419&keyword=딥러닝
#
#
# 10 번째 정보를 추출하고 있습니다============
# 1.번호 : 10
# 2.제목 : ARM Compute Library와 Neural Networks API를 이용한 임베디드 딥러닝 시스템 개발
# 3.작성자 : 이정헌
# 4.소속기관 : 인천대학교 일반대학원
# 5.발표년도 : 2019
# 6.학위여부 : 국내석사
# 7.초록내용 : 딥러닝 어플리케이션의 수요는 점차 증가하고 있으며, 사용자들은 엣지 디바이스 환경에서 딥러닝 모델의 추론 결과를 사용하기를 원한다. 모바일 산업의 발전과 함께 임베디드 SoC의 성능...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=2cf5314be403214cffe0bdc3ef48d419&keyword=딥러닝
#
#
# 2 페이지 내용 수집 시작합니다 =======================
#
#
# 11 번째 정보를 추출하고 있습니다============
# 1.번호 : 11
# 2.제목 : 인공지능 딥러닝 소개와 보안 동향
# 3.작성자 : 박용병
# 4.소속기관 : 공주대학교 일반대학원
# 5.발표년도 : 2021
# 6.학위여부 : 국내석사
# 7.초록내용 : 최근 인공지능은 전 세계적으로 정치, 사회, 교육 등 산업 전반에 걸쳐 주목을 받고 있으며 4차 산업혁명의 중심이 되는 기술로 특히 보안업계에서 뜨거운 관심을 받고 있다. 보안 기술을 위...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=555098a99255a50dffe0bdc3ef48d419&keyword=딥러닝
#
#
# 12 번째 정보를 추출하고 있습니다============
# 1.번호 : 12
# 2.제목 : 딥러닝을 이용한 시계열 데이터  군집화에 관한 연구
# 3.작성자 : 윤동희
# 4.소속기관 : 명지대학교 대학원
# 5.발표년도 : 2019
# 6.학위여부 : 국내석사
# 7.초록내용 : 최근 4차 산업혁명과 더불어 딥러닝을 활용한 스마트 공장, 스마트 시티, 인공지능 서비스 등이 활발히 추진되고 있다. 딥러닝이 다양한 분야에서 좋은 성능을 보이고 있는 이유는 딥러닝이 ...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=ffcbd85e9769d922ffe0bdc3ef48d419&keyword=딥러닝
#
#
# 13 번째 정보를 추출하고 있습니다============
# 1.번호 : 13
# 2.제목 : 비정형 데이터를 위한 딥러닝 기반의 군집화 알고리즘 개발
# 3.작성자 : 이철희
# 4.소속기관 : 명지대학교 대학원
# 5.발표년도 : 2020
# 6.학위여부 : 국내석사
# 7.초록내용 : 1990년대 이후 여러 분야의 산업 기술 발전으로 인해 생성되는 데이터의 양이 많아지면서 데이터를 기반으로 스스로 학습하는 기계학습 분야에 대한 관심이 많아지기 시작했다. 하지만 생성...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=ef74c0de09a31fd9ffe0bdc3ef48d419&keyword=딥러닝
#
#
# 14 번째 정보를 추출하고 있습니다============
# 1.번호 : 14
# 2.제목 : 딥 러닝을 이용한 고속도로 교통사고 예측모델 개발
# 3.작성자 : 류종득
# 4.소속기관 : 아주대학교 아주대학교 일반대학원
# 5.발표년도 : 2018
# 6.학위여부 : 국내박사
# 7.초록내용 : 기존에는 대부분의 교통사고 자료 분석이 전통적인 통계적 방법인 포아송 회귀모형 또는 음이항 회귀모형 등을 기반으로 시행되어져 왔다. 이러한 통계적 방법은 교통사고와 관련된 다양한...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=c34d8a4c612be833ffe0bdc3ef48d419&keyword=딥러닝
#
#
# 15 번째 정보를 추출하고 있습니다============
# 1.번호 : 15
# 2.제목 : 딥러닝 소개와 금융업 적용 사례
# 3.작성자 : 박원기
# 4.소속기관 : 고려대학교
# 5.발표년도 : 2018
# 6.학위여부 : 국내석사
# 7.초록내용 : 2016년 3월 구글 딥마인드의 바둑 인공지능 알파고(AlphaGo)와 이세돌 9단과의 세기의 바둑 대결을 통해 딥러닝(Deep Learning)을 포함한 인공지능에 대해 사람들의 관심이 높아졌다. 딥러닝은 1980년...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=9fc51c20020708a4ffe0bdc3ef48d419&keyword=딥러닝
#
#
# 16 번째 정보를 추출하고 있습니다============
# 1.번호 : 16
# 2.제목 : 딥러닝 알고리즘을 이용한 자동차 현가장치 부품 수요예측 모델에 관한 연구
# 3.작성자 : 이상길
# 4.소속기관 : 동아대학교 대학원
# 5.발표년도 : 2023
# 6.학위여부 : 국내석사
# 7.초록내용 : 현재, 자동차 산업은 친환경 전기차·자율주행·공유 등의 핵심 가치를 중심으로 패러다임의 변화가 급격하게 진행되고 있다. 또한 갈수록 치열해지는 기업 간의 경쟁과 환경변화에서 살아�...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=2f5ca1f1e83fe178ffe0bdc3ef48d419&keyword=딥러닝
#
#
# 17 번째 정보를 추출하고 있습니다============
# 1.번호 : 17
# 2.제목 : 객체 탐지를 위한 경량 딥러닝 최적화 연구
# 3.작성자 : 이한해솔
# 4.소속기관 : 고려대학교
# 5.발표년도 : 2020
# 6.학위여부 : 국내석사
# 7.초록내용 : 최근 Convolutional Neural Network(CNN) 기반 네트워크 모델에 관한 연구가 증가함에 따라 이를 응용한 딥러닝 연구도 함께 진행되고 있는 가운데, 스마트폰, 임베디드 보드 같은 소형기기(Device)에서 ...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=4ddbf36e5382a681ffe0bdc3ef48d419&keyword=딥러닝
#
#
# 18 번째 정보를 추출하고 있습니다============
# 1.번호 : 18
# 2.제목 : 딥러닝 기법을 활용한 매립가스 발전소의 메탄가스 농도 및 전력생산량 예측
# 3.작성자 : 원승현
# 4.소속기관 : 서울과학기술대학교
# 5.발표년도 : 2018
# 6.학위여부 : 국내박사
# 7.초록내용 : 본 연구에서는 매립가스 발전소 운영에 필요한 빅데이터・인공지능 모델 개발의 일환으로 매립장 매립가스 발전소를 대상으로 발전소 운영 데이터들을 검토하여 데이터들 간의 관계를 알...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=5c489847e988840dffe0bdc3ef48d419&keyword=딥러닝
#
#
# 19 번째 정보를 추출하고 있습니다============
# 1.번호 : 19
# 2.제목 : 딥러닝ㆍUAVㆍLiDAR 융합기술기반 산림자원정보시스템 구축에 관한 연구
# 3.작성자 : 심우담
# 4.소속기관 : 강원대학교 대학원
# 5.발표년도 : 2022
# 6.학위여부 : 국내박사
# 7.초록내용 : At the 46th Davos Forum held in Switzerland in 2016, the Fourth Industrial Revolution was presented as the plan for global economic reconstruction and economic growth, after the global financial crisis. In accordance, nations around the world have bee...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=44c3f4ac7ddfe8dbffe0bdc3ef48d419&keyword=딥러닝
#
#
# 20 번째 정보를 추출하고 있습니다============
# 1.번호 : 20
# 2.제목 : 딥러닝 모델에 따른 당뇨성 망막질환 안저영상의 자동진단 성능평가
# 3.작성자 : 김지율
# 4.소속기관 : 부산가톨릭대학교 대학원
# 5.발표년도 : 2020
# 6.학위여부 : 국내박사
# 7.초록내용 : Purpose: In recent years, the application of deep learning to the medical and biomedical research fields is increasing exponentially. Convolutional neural networks have high accuracy in the field of image recognition. It is improving accuracy. However...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=99f1f572fe49a08cffe0bdc3ef48d419&keyword=딥러닝
#
#
# 3 페이지 내용 수집 시작합니다 =======================
#
#
# 21 번째 정보를 추출하고 있습니다============
# 1.번호 : 21
# 2.제목 : 샴 네트워크와 주목 모듈을 활용한 딥러닝 기반 건물객체의 변화탐지
# 3.작성자 : 모준상
# 4.소속기관 : 충북대학교
# 5.발표년도 : 2022
# 6.학위여부 : 국내석사
# 7.초록내용 : 본 연구는 다시기 정사영상 속 변화하는 건물객체를 탐지하기 위한 딥러닝 네트워크를 제안하였다.의미론적 분할에서 사용되는 대표적인 인코더-디코더 기반 딥러닝 네트워크 중 하나인  U...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=49841029ab15ac4affe0bdc3ef48d419&keyword=딥러닝
#
#
# 22 번째 정보를 추출하고 있습니다============
# 1.번호 : 22
# 2.제목 : 다중모드 광섬유에서 딥러닝을 이용한 광학 이미지 전송 연구
# 3.작성자 : 박성민
# 4.소속기관 : 아주대학교
# 5.발표년도 : 2021
# 6.학위여부 : 국내석사
# 7.초록내용 : 스펙클(speckle) 패턴은 산란 매질을 진행하는 빛의 무작위한 위상(phase) 변화와 간섭에 의해 나타난다. 이러한 현상은 공간적으로 결맞은(spatially coherent) 빛이 거친 표면에서 반사되거나 생체 ...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=1dcf386bbb1d9115ffe0bdc3ef48d419&keyword=딥러닝
#
#
# 23 번째 정보를 추출하고 있습니다============
# 1.번호 : 23
# 2.제목 : Metamorphic Relations를 이용한 이미지 분류 딥러닝 모델의 정확성 평가 방법
# 3.작성자 : 송민주
# 4.소속기관 : 부산대학교 대학원
# 5.발표년도 : 2019
# 6.학위여부 : 국내석사
# 7.초록내용 : The Image Classification Deep Learning model is a model that predicts the type of test image data by learning the learning image data. Image classification Deep Learning models are used for Naver's Smart Lens and Google's. However, there is a problem ...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=325d3cc016d16e61ffe0bdc3ef48d419&keyword=딥러닝
#
#
# 24 번째 정보를 추출하고 있습니다============
# 1.번호 : 24
# 2.제목 : 분산 딥러닝에서 통신 오버헤드를 줄이기 위해 레이어를 오버래핑하는 하이브리드 올-리듀스 기법
# 3.작성자 : 김대현
# 4.소속기관 : 아주대학교
# 5.발표년도 : 2021
# 6.학위여부 : 국내석사
# 7.초록내용 : 머신 러닝 기법 중 하나인 딥러닝은 이전에는 해결할 수 없다고 생각했던 문제에 대한 해결책을 제공하고 있다. 이에 따라 음성 인식, 시각적 객체 인식, 텍스트 처리와 같은 실제 응용 분야...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=afb0b0fa211769daffe0bdc3ef48d419&keyword=딥러닝
#
#
# 25 번째 정보를 추출하고 있습니다============
# 1.번호 : 25
# 2.제목 : 단순 방사선 촬영 영상에서 딥러닝 알고리즘의 객체 검출법을 이용한 두개골 골절의 자동화 진단
# 3.작성자 : 정태석
# 4.소속기관 : 가천대학교 일반대학원
# 5.발표년도 : 2021
# 6.학위여부 : 국내박사
# 7.초록내용 : 두부 외상 환자에서 두개골 골절은 뇌출혈, 감염 등의 악화 가능성이 있기 때문에 신속하고 정확히 진단해야 한다. 두개골 단순 방사선 촬영은 두개골 골절을 진단하는 가장 기본적인 영상 ...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=6eb557a0f7773fd1ffe0bdc3ef48d419&keyword=딥러닝
#
#
# 26 번째 정보를 추출하고 있습니다============
# 1.번호 : 26
# 2.제목 : 딥러닝이 적용된 게임 밸런스에 관한 연구 : 게임 기획 방법론의 관점으로
# 3.작성자 : 전준현
# 4.소속기관 : 건국대학교 대학원
# 5.발표년도 : 2017
# 6.학위여부 : 국내박사
# 7.초록내용 : Recently, software production has gradually become easier with the developments of computer performance and technology of programming language. In the past, it was difficult to produce even a program in a simple form, for people other than experts who...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=a6fbc7d1a0ede2c0ffe0bdc3ef48d419&keyword=딥러닝
#
#
# 27 번째 정보를 추출하고 있습니다============
# 1.번호 : 27
# 2.제목 : 시설물 안전 점검을 위한 딥러닝 기반 균열 탐지 -터널 콘크리트 라이닝을 중심으로-
# 3.작성자 : 배수현
# 4.소속기관 : 서울시립대학교 일반대학원
# 5.발표년도 : 2023
# 6.학위여부 : 국내석사
# 7.초록내용 : 인력 기반 터널 점검은 점검자의 주관적인 판단에 영향을 받으며 지속적인 이력 관리가 어렵다. 따라서 최근에는 터널을 비롯한 여러 가지 기반 시설물에 발생한 콘크리트 균열을 영상과 딥...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=4081c3745a4e1957ffe0bdc3ef48d419&keyword=딥러닝
#
#
# 28 번째 정보를 추출하고 있습니다============
# 1.번호 : 28
# 2.제목 : 딥러닝 모델의 앙상블을 활용한 근적외선 얼굴 인식 방법
# 3.작성자 : 유지은
# 4.소속기관 : 한양대학교 대학원
# 5.발표년도 : 2019
# 6.학위여부 : 국내석사
# 7.초록내용 : Recently, deep learning-based research has been actively conducted, and RGB face recognition algorithms applying deep learning achieve high performance. It is easy to train a complex deep learning model that can obtain high performance, because a lot ...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=1ba9691d06d367c3ffe0bdc3ef48d419&keyword=딥러닝
#
#
# 29 번째 정보를 추출하고 있습니다============
# 1.번호 : 29
# 2.제목 : 딥러닝과 증강현실을 활용한 스마트 과업 지원에 관한 연구
# 3.작성자 : 박경범
# 4.소속기관 : 전남대학교
# 5.발표년도 : 2023
# 6.학위여부 : 국내박사
# 7.초록내용 : 최근 가상이나 추상을 의미하는 메타(Meta)와 현실 세계를 의미하는 유니버스(Universe)의 합성어인 메타버스(Metaverse) 기술이 많은 각광을 받고 있다. 메타버스는 가상과 현실이 상호작용하고, ...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=93a96f03e44ea257ffe0bdc3ef48d419&keyword=딥러닝
#
#
# 30 번째 정보를 추출하고 있습니다============
# 1.번호 : 30
# 2.제목 : 정제형 일반의약품 인식서비스를 위한 딥러닝 기반의 모바일 플랫폼
# 3.작성자 : 민동희
# 4.소속기관 : 상지대학교 일반대학원
# 5.발표년도 : 2019
# 6.학위여부 : 국내석사
# 7.초록내용 : 현재 한국의 의약품 산업은 주요 성장동력산업으로 분류되고 있으며, 폭발적인 성장을 보이고 있다. 하지만 가파른 성장곡선에 비해 의약품 소비자들의 의약품 관리 능력 및 복용 지식수준...
# 8.논문 URL 주소: http://www.riss.kr/search/detail/DetailView.do?p_mat_type=be54d9b8bc7cdb09&control_no=9dd5630f493070d4ffe0bdc3ef48d419&keyword=딥러닝
# 요청하신 작업이 모두 완료되었습니다
# 요청하신 데이터 수집 작업이 정상적으로 완료되었습니다
